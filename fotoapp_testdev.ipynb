# %% [markdown]
# PROYECTO 2 - Procesamiento de Imagenes - Domenico Alejandro

# %% [markdown]
# MONTO EL DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importo el Fotoapp

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/tp2_python/entrega')

import fotoapp

from fotoapp import redimensionar_imagen, ajustar_contraste, aplicar_filtro, generar_boceto, menu

# %% [markdown]
# LISTO LA RUTA PARA VER SI LAS IMAGENES ESTAN

# %%
import os
ruta = "/content/drive/MyDrive/Colab Notebooks/tp2_python/entrega/img/"
archivos = os.listdir(ruta)
archivos
# Out:
# ['perrito.png', 'gatito.png', 'persona_clara.png', 'persona_oscura.png']

# %% [markdown]
# LLAMO AL MODULO PARA PROBAR LAS FUNCIONES (PRIMERO LAS PRUEBO INDEPENDIENTEMENTE, LUEGO CON EL MENU)

# %% [markdown]
# 1-REDIMENSIONAR IMAGEN

# %%
ruta_imagen = "/content/drive/MyDrive/Colab Notebooks/tp2_python/entrega/img/gatito.png"
plataforma = "Instagram"
redimensionar_imagen(ruta_imagen, plataforma)
# Out:
# Error: No se encontró la imagen en la ruta especificada: /content/drive/MyDrive/Colab Notebooks/tp2_python/img/gatito.png

# %% [markdown]
# 2-AJUSTAR CONTRASTE

# %%
ruta_imagen_oscura = "/content/drive/MyDrive/Colab Notebooks/tp2_python/entrega/img/gatito.png"
ruta_imagen_clara = "/content/drive/MyDrive/Colab Notebooks/tp2_python/entrega/img/perrito.png"

#oscura
ajustar_contraste(ruta_imagen_oscura)

#clara
ajustar_contraste(ruta_imagen_clara)

# %% [markdown]
# 3-APLICAR FILTROS

# %%
ruta_imagen = "/content/drive/MyDrive/Colab Notebooks/tp2_python/entrega/img/perrito.png"
filtro_elegido = "DETAIL"
aplicar_filtro(ruta_imagen, filtro_elegido)
# Out:
# Imagen con filtro DETAIL guardada como imagen_DETAIL.png
# Imagen con todos los filtros guardada como todos_los_filtros.png

# %% [markdown]
# 4-GENERAR BOCETO

# %%
ruta_imagen="/content/drive/MyDrive/Colab Notebooks/tp2_python/entrega/img/persona_clara.png"
generar_boceto(ruta_imagen, persona=True)
ruta_imagen="/content/drive/MyDrive/Colab Notebooks/tp2_python/entrega/img/persona_oscura.png"
generar_boceto(ruta_imagen, persona=True)
# Out:
# Boceto generado guardado como boceto_generado.png
# Boceto generado guardado como boceto_generado.png

# %% [markdown]
# 5-MENU DE OPCIONES

# %%
menu()
# Out:
# --- Menú de Opciones ---
# 1. Redimensionar imagen para redes sociales.
# 2. Ajustar contraste de la imagen.
# 3. Aplicar filtro a la imagen.
# 4. Generar boceto de la imagen.
# 5. Salir.
#
# Seleccione una opción (1-5): 2
#
#
# Debe redimensionar una imagen primero (opción 1) antes de continuar.
#
# --- Menú de Opciones ---
# 1. Redimensionar imagen para redes sociales.
# 2. Ajustar contraste de la imagen.
# 3. Aplicar filtro a la imagen.
# 4. Generar boceto de la imagen.
# 5. Salir.
#
# Seleccione una opción (1-5): 1
#
# Ingrese la ruta de la imagen: /content/drive/MyDrive/Colab Notebooks/tp2_python/entrega/img/persona_oscura.png
# Ingrese la plataforma (Youtube, Instagram, Twitter, Facebook): Facebook
#
# Imagen redimensionada correctamente. Puede continuar con otras opciones.
#
# --- Menú de Opciones ---
# 1. Redimensionar imagen para redes sociales.
# 2. Ajustar contraste de la imagen.
# 3. Aplicar filtro a la imagen.
# 4. Generar boceto de la imagen.
# 5. Salir.
#
# ...
